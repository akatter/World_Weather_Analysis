# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create 2000 sets of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 1 | quatre cocos
# Processing Record 4 of Set 1 | tuktoyaktuk
# Processing Record 5 of Set 1 | kruisfontein
# Processing Record 6 of Set 1 | mahebourg
# Processing Record 7 of Set 1 | kavieng
# Processing Record 8 of Set 1 | nome
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | lira
# Processing Record 11 of Set 1 | constitucion
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | sibolga
# Processing Record 14 of Set 1 | guelengdeng
# City not found. Skipping...
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | baykit
# Processing Record 17 of Set 1 | padang
# Processing Record 18 of Set 1 | nevyansk
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | bandarbeyla
# Processing Record 22 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 1 | kaitangata
# Processing Record 25 of Set 1 | solnechnyy
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | carnarvon
# Processing Record 29 of Set 1 | jibuti
# Processing Record 30 of Set 1 | calabozo
# Processing Record 31 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 1 | henties bay
# Processing Record 33 of Set 1 | victoria
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | nador
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | buchanan
# Processing Record 39 of Set 1 | arkhangelskoye
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | albemarle
# Processing Record 42 of Set 1 | jiroft
# City not found. Skipping...
# Processing Record 43 of Set 1 | borovskoy
# Processing Record 44 of Set 1 | shahr-e kord
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | nikolskoye
# Processing Record 48 of Set 1 | hasaki
# Processing Record 49 of Set 1 | yumen
# Processing Record 50 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 2 | havre-saint-pierre
# Processing Record 2 of Set 2 | belyy yar
# Processing Record 3 of Set 2 | kavaratti
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | kahului
# Processing Record 7 of Set 2 | qasigiannguit
# Processing Record 8 of Set 2 | east london
# Processing Record 9 of Set 2 | pangnirtung
# Processing Record 10 of Set 2 | gambita
# City not found. Skipping...
# Processing Record 11 of Set 2 | tahta
# Processing Record 12 of Set 2 | tecoanapa
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | tilbury
# Processing Record 15 of Set 2 | bethel
# Processing Record 16 of Set 2 | laguna
# Processing Record 17 of Set 2 | bengkulu
# Processing Record 18 of Set 2 | fortuna
# Processing Record 19 of Set 2 | tautira
# Processing Record 20 of Set 2 | barrow
# Processing Record 21 of Set 2 | sur
# Processing Record 22 of Set 2 | geraldton
# Processing Record 23 of Set 2 | gazni
# City not found. Skipping...
# Processing Record 24 of Set 2 | luderitz
# Processing Record 25 of Set 2 | cherskiy
# Processing Record 26 of Set 2 | kutum
# Processing Record 27 of Set 2 | lompoc
# Processing Record 28 of Set 2 | san jose
# Processing Record 29 of Set 2 | pevek
# Processing Record 30 of Set 2 | ellensburg
# Processing Record 31 of Set 2 | qaanaaq
# Processing Record 32 of Set 2 | severo-kurilsk
# Processing Record 33 of Set 2 | namikupa
# Processing Record 34 of Set 2 | velesin
# Processing Record 35 of Set 2 | dingle
# Processing Record 36 of Set 2 | fairbanks
# Processing Record 37 of Set 2 | yerbogachen
# Processing Record 38 of Set 2 | nowa ruda
# Processing Record 39 of Set 2 | santa maria
# Processing Record 40 of Set 2 | quakenbruck
# Processing Record 41 of Set 2 | rabo de peixe
# Processing Record 42 of Set 2 | humberto de campos
# Processing Record 43 of Set 2 | grants
# Processing Record 44 of Set 2 | hilo
# Processing Record 45 of Set 2 | tamsalu
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | saskylakh
# Processing Record 48 of Set 2 | provideniya
# Processing Record 49 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 2 | lianyuan
# Processing Record 1 of Set 3 | loukhi
# Processing Record 2 of Set 3 | gamba
# Processing Record 3 of Set 3 | brigantine
# Processing Record 4 of Set 3 | dikson
# Processing Record 5 of Set 3 | tilichiki
# Processing Record 6 of Set 3 | rawson
# Processing Record 7 of Set 3 | shahr-e babak
# Processing Record 8 of Set 3 | acin
# City not found. Skipping...
# Processing Record 9 of Set 3 | dwarka
# Processing Record 10 of Set 3 | port augusta
# Processing Record 11 of Set 3 | clyde river
# Processing Record 12 of Set 3 | yellowknife
# Processing Record 13 of Set 3 | shache
# Processing Record 14 of Set 3 | lorengau
# Processing Record 15 of Set 3 | avarua
# Processing Record 16 of Set 3 | zyryanka
# Processing Record 17 of Set 3 | isangel
# Processing Record 18 of Set 3 | comodoro rivadavia
# Processing Record 19 of Set 3 | butaritari
# Processing Record 20 of Set 3 | camaqua
# Processing Record 21 of Set 3 | georgetown
# Processing Record 22 of Set 3 | busselton
# Processing Record 23 of Set 3 | matane
# Processing Record 24 of Set 3 | nanortalik
# Processing Record 25 of Set 3 | parati
# Processing Record 26 of Set 3 | kirkwall
# Processing Record 27 of Set 3 | manggar
# Processing Record 28 of Set 3 | lebu
# Processing Record 29 of Set 3 | diu
# Processing Record 30 of Set 3 | muroto
# Processing Record 31 of Set 3 | agua prieta
# Processing Record 32 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 3 | port hedland
# Processing Record 34 of Set 3 | alugan
# Processing Record 35 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 3 | vaini
# Processing Record 37 of Set 3 | robertsport
# Processing Record 38 of Set 3 | faanui
# Processing Record 39 of Set 3 | vila velha
# Processing Record 40 of Set 3 | hambantota
# Processing Record 41 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 3 | taoudenni
# Processing Record 43 of Set 3 | mount gambier
# Processing Record 44 of Set 3 | kidal
# Processing Record 45 of Set 3 | saint-francois
# Processing Record 46 of Set 3 | bloomfield
# Processing Record 47 of Set 3 | sitka
# Processing Record 48 of Set 3 | yulara
# Processing Record 49 of Set 3 | ribeira grande
# Processing Record 50 of Set 3 | martapura
# Processing Record 1 of Set 4 | chokurdakh
# Processing Record 2 of Set 4 | tuatapere
# Processing Record 3 of Set 4 | upernavik
# Processing Record 4 of Set 4 | port lincoln
# Processing Record 5 of Set 4 | cabo san lucas
# Processing Record 6 of Set 4 | durango
# Processing Record 7 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 4 | romilly-sur-seine
# Processing Record 9 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 4 | kushnarenkovo
# Processing Record 11 of Set 4 | epe
# Processing Record 12 of Set 4 | saint-philippe
# Processing Record 13 of Set 4 | san quintin
# Processing Record 14 of Set 4 | matrei
# City not found. Skipping...
# Processing Record 15 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 4 | arraial do cabo
# Processing Record 17 of Set 4 | odweyne
# Processing Record 18 of Set 4 | atikokan
# Processing Record 19 of Set 4 | tateyama
# Processing Record 20 of Set 4 | gizycko
# Processing Record 21 of Set 4 | benghazi
# Processing Record 22 of Set 4 | kungsbacka
# Processing Record 23 of Set 4 | ponta do sol
# Processing Record 24 of Set 4 | longyearbyen
# Processing Record 25 of Set 4 | tasiilaq
# Processing Record 26 of Set 4 | taltal
# Processing Record 27 of Set 4 | viedma
# Processing Record 28 of Set 4 | souillac
# Processing Record 29 of Set 4 | mehamn
# Processing Record 30 of Set 4 | oktyabrskoye
# Processing Record 31 of Set 4 | merauke
# Processing Record 32 of Set 4 | cascais
# Processing Record 33 of Set 4 | palmer
# Processing Record 34 of Set 4 | minusinsk
# Processing Record 35 of Set 4 | pilar
# Processing Record 36 of Set 4 | westpunt
# City not found. Skipping...
# Processing Record 37 of Set 4 | ulladulla
# Processing Record 38 of Set 4 | narsaq
# Processing Record 39 of Set 4 | santa ana
# Processing Record 40 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 41 of Set 4 | the pas
# Processing Record 42 of Set 4 | cabedelo
# Processing Record 43 of Set 4 | siniscola
# Processing Record 44 of Set 4 | kamienna gora
# Processing Record 45 of Set 4 | mandalgovi
# Processing Record 46 of Set 4 | joao pinheiro
# Processing Record 47 of Set 4 | mar del plata
# Processing Record 48 of Set 4 | ilulissat
# Processing Record 49 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 4 | labytnangi
# Processing Record 1 of Set 5 | lokosovo
# Processing Record 2 of Set 5 | lata
# Processing Record 3 of Set 5 | songea
# Processing Record 4 of Set 5 | sukhumi
# Processing Record 5 of Set 5 | leninsk
# Processing Record 6 of Set 5 | broome
# Processing Record 7 of Set 5 | vardo
# Processing Record 8 of Set 5 | puerto ayora
# Processing Record 9 of Set 5 | puerto escondido
# Processing Record 10 of Set 5 | itigi
# Processing Record 11 of Set 5 | llangefni
# Processing Record 12 of Set 5 | port elizabeth
# Processing Record 13 of Set 5 | svetlogorsk
# Processing Record 14 of Set 5 | kattivakkam
# Processing Record 15 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 16 of Set 5 | nyurba
# Processing Record 17 of Set 5 | krasnoselkup
# Processing Record 18 of Set 5 | poum
# Processing Record 19 of Set 5 | plettenberg bay
# Processing Record 20 of Set 5 | salalah
# Processing Record 21 of Set 5 | tual
# Processing Record 22 of Set 5 | mpika
# Processing Record 23 of Set 5 | thompson
# Processing Record 24 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 5 | poyarkovo
# Processing Record 26 of Set 5 | ankang
# Processing Record 27 of Set 5 | kamina
# Processing Record 28 of Set 5 | erzin
# Processing Record 29 of Set 5 | camabatela
# Processing Record 30 of Set 5 | wilmington
# Processing Record 31 of Set 5 | santa cruz del sur
# Processing Record 32 of Set 5 | gurskoye
# City not found. Skipping...
# Processing Record 33 of Set 5 | richards bay
# Processing Record 34 of Set 5 | barra da estiva
# Processing Record 35 of Set 5 | sao filipe
# Processing Record 36 of Set 5 | hovd
# Processing Record 37 of Set 5 | torbay
# Processing Record 38 of Set 5 | natal
# Processing Record 39 of Set 5 | maldonado
# Processing Record 40 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 5 | landeck
# Processing Record 42 of Set 5 | kuah
# Processing Record 43 of Set 5 | la ronge
# Processing Record 44 of Set 5 | saint-augustin
# Processing Record 45 of Set 5 | tiksi
# Processing Record 46 of Set 5 | karratha
# Processing Record 47 of Set 5 | san patricio
# Processing Record 48 of Set 5 | haines junction
# Processing Record 49 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 5 | bilma
# Processing Record 1 of Set 6 | birin
# Processing Record 2 of Set 6 | dharur
# Processing Record 3 of Set 6 | matara
# Processing Record 4 of Set 6 | yar-sale
# Processing Record 5 of Set 6 | samarai
# Processing Record 6 of Set 6 | manokwari
# Processing Record 7 of Set 6 | strelka
# Processing Record 8 of Set 6 | ambilobe
# Processing Record 9 of Set 6 | coquimbo
# Processing Record 10 of Set 6 | kheralu
# Processing Record 11 of Set 6 | iaciara
# Processing Record 12 of Set 6 | mitsamiouli
# Processing Record 13 of Set 6 | port-gentil
# Processing Record 14 of Set 6 | margate
# Processing Record 15 of Set 6 | esperance
# Processing Record 16 of Set 6 | saint-pierre
# Processing Record 17 of Set 6 | charleville
# Processing Record 18 of Set 6 | rurrenabaque
# Processing Record 19 of Set 6 | tumaco
# Processing Record 20 of Set 6 | antalaha
# Processing Record 21 of Set 6 | norman wells
# Processing Record 22 of Set 6 | zhigansk
# Processing Record 23 of Set 6 | port moresby
# Processing Record 24 of Set 6 | harbin
# Processing Record 25 of Set 6 | smidovich
# Processing Record 26 of Set 6 | ahuimanu
# Processing Record 27 of Set 6 | zadonsk
# Processing Record 28 of Set 6 | panaba
# Processing Record 29 of Set 6 | mabai
# Processing Record 30 of Set 6 | ferkessedougou
# Processing Record 31 of Set 6 | cidreira
# Processing Record 32 of Set 6 | klaksvik
# Processing Record 33 of Set 6 | okahandja
# Processing Record 34 of Set 6 | birjand
# Processing Record 35 of Set 6 | san ramon
# Processing Record 36 of Set 6 | puerto madryn
# Processing Record 37 of Set 6 | araouane
# Processing Record 38 of Set 6 | port hardy
# Processing Record 39 of Set 6 | ziyang
# Processing Record 40 of Set 6 | alice springs
# Processing Record 41 of Set 6 | yakeshi
# Processing Record 42 of Set 6 | tucumcari
# Processing Record 43 of Set 6 | townsville
# Processing Record 44 of Set 6 | penzance
# Processing Record 45 of Set 6 | paamiut
# Processing Record 46 of Set 6 | sobolevo
# Processing Record 47 of Set 6 | ouadda
# Processing Record 48 of Set 6 | sakakah
# Processing Record 49 of Set 6 | san cristobal
# Processing Record 50 of Set 6 | golden rock
# City not found. Skipping...
# Processing Record 1 of Set 7 | saint george
# Processing Record 2 of Set 7 | kenai
# Processing Record 3 of Set 7 | hirara
# Processing Record 4 of Set 7 | lubango
# Processing Record 5 of Set 7 | chavakkad
# Processing Record 6 of Set 7 | nantucket
# Processing Record 7 of Set 7 | chumikan
# Processing Record 8 of Set 7 | qurayyat
# Processing Record 9 of Set 7 | namibe
# Processing Record 10 of Set 7 | necochea
# Processing Record 11 of Set 7 | inhambane
# Processing Record 12 of Set 7 | phan thiet
# Processing Record 13 of Set 7 | los llanos de aridane
# Processing Record 14 of Set 7 | ponta delgada
# Processing Record 15 of Set 7 | komsomolskiy
# Processing Record 16 of Set 7 | fort nelson
# Processing Record 17 of Set 7 | kamaishi
# Processing Record 18 of Set 7 | kizilskoye
# Processing Record 19 of Set 7 | jaisalmer
# Processing Record 20 of Set 7 | shubarkuduk
# Processing Record 21 of Set 7 | katsuura
# Processing Record 22 of Set 7 | vanavara
# Processing Record 23 of Set 7 | arvika
# Processing Record 24 of Set 7 | ilembula
# Processing Record 25 of Set 7 | bafoulabe
# Processing Record 26 of Set 7 | yangshe
# Processing Record 27 of Set 7 | tevaitoa
# Processing Record 28 of Set 7 | khatanga
# Processing Record 29 of Set 7 | bredasdorp
# Processing Record 30 of Set 7 | college
# Processing Record 31 of Set 7 | shimoda
# Processing Record 32 of Set 7 | baraki barak
# Processing Record 33 of Set 7 | hamilton
# Processing Record 34 of Set 7 | kathmandu
# Processing Record 35 of Set 7 | lavrentiya
# Processing Record 36 of Set 7 | kieta
# Processing Record 37 of Set 7 | miracema do tocantins
# Processing Record 38 of Set 7 | bowen
# Processing Record 39 of Set 7 | freeport
# Processing Record 40 of Set 7 | sao joao da barra
# Processing Record 41 of Set 7 | beringovskiy
# Processing Record 42 of Set 7 | panormos
# Processing Record 43 of Set 7 | kanigoro
# Processing Record 44 of Set 7 | umm lajj
# Processing Record 45 of Set 7 | zapolyarnyy
# Processing Record 46 of Set 7 | channel-port aux basques
# Processing Record 47 of Set 7 | talnakh
# Processing Record 48 of Set 7 | husavik
# Processing Record 49 of Set 7 | zhezkazgan
# Processing Record 50 of Set 7 | denau
# City not found. Skipping...
# Processing Record 1 of Set 8 | ajdabiya
# Processing Record 2 of Set 8 | lexington
# Processing Record 3 of Set 8 | faya
# Processing Record 4 of Set 8 | baykalsk
# Processing Record 5 of Set 8 | ancud
# Processing Record 6 of Set 8 | honningsvag
# Processing Record 7 of Set 8 | bambous virieux
# Processing Record 8 of Set 8 | shahumyan
# Processing Record 9 of Set 8 | vangaindrano
# Processing Record 10 of Set 8 | lasa
# Processing Record 11 of Set 8 | nouadhibou
# Processing Record 12 of Set 8 | teguldet
# Processing Record 13 of Set 8 | asau
# Processing Record 14 of Set 8 | dujuma
# City not found. Skipping...
# Processing Record 15 of Set 8 | rocha
# Processing Record 16 of Set 8 | mount isa
# Processing Record 17 of Set 8 | avera
# Processing Record 18 of Set 8 | sisimiut
# Processing Record 19 of Set 8 | berlevag
# Processing Record 20 of Set 8 | kyshtovka
# Processing Record 21 of Set 8 | gayeri
# Processing Record 22 of Set 8 | la roda
# Processing Record 23 of Set 8 | jatiroto
# Processing Record 24 of Set 8 | okhotsk
# Processing Record 25 of Set 8 | alto araguaia
# Processing Record 26 of Set 8 | peniche
# Processing Record 27 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 8 | killybegs
# Processing Record 29 of Set 8 | biltine
# Processing Record 30 of Set 8 | vila
# Processing Record 31 of Set 8 | pitiquito
# Processing Record 32 of Set 8 | dublin
# Processing Record 33 of Set 8 | bonthe
# Processing Record 34 of Set 8 | aklavik
# Processing Record 35 of Set 8 | fort-shevchenko
# Processing Record 36 of Set 8 | mahibadhoo
# Processing Record 37 of Set 8 | mopipi
# Processing Record 38 of Set 8 | rancho santa margarita
# Processing Record 39 of Set 8 | urumqi
# Processing Record 40 of Set 8 | zhob
# Processing Record 41 of Set 8 | abbeville
# Processing Record 42 of Set 8 | matola
# Processing Record 43 of Set 8 | cosamaloapan
# Processing Record 44 of Set 8 | kununurra
# Processing Record 45 of Set 8 | chuy
# Processing Record 46 of Set 8 | niquelandia
# Processing Record 47 of Set 8 | petropavlovka
# Processing Record 48 of Set 8 | codrington
# Processing Record 49 of Set 8 | mokrousovo
# Processing Record 50 of Set 8 | hami
# Processing Record 1 of Set 9 | klyuchi
# Processing Record 2 of Set 9 | lypnyazhka
# Processing Record 3 of Set 9 | barcelos
# Processing Record 4 of Set 9 | vestmanna
# Processing Record 5 of Set 9 | lincoln
# Processing Record 6 of Set 9 | khandbari
# Processing Record 7 of Set 9 | anton lizardo
# Processing Record 8 of Set 9 | mindelo
# Processing Record 9 of Set 9 | danao
# Processing Record 10 of Set 9 | jacareacanga
# Processing Record 11 of Set 9 | sandovo
# Processing Record 12 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 13 of Set 9 | asfi
# Processing Record 14 of Set 9 | bubaque
# Processing Record 15 of Set 9 | lianran
# Processing Record 16 of Set 9 | bardiyah
# Processing Record 17 of Set 9 | chibuto
# Processing Record 18 of Set 9 | dongying
# Processing Record 19 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 20 of Set 9 | mercedes
# Processing Record 21 of Set 9 | varhaug
# Processing Record 22 of Set 9 | borujan
# City not found. Skipping...
# Processing Record 23 of Set 9 | ruteng
# Processing Record 24 of Set 9 | nueva guinea
# Processing Record 25 of Set 9 | touros
# Processing Record 26 of Set 9 | saint-louis
# Processing Record 27 of Set 9 | salinas
# Processing Record 28 of Set 9 | srednekolymsk
# Processing Record 29 of Set 9 | kulob
# Processing Record 30 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 9 | arrecife
# Processing Record 32 of Set 9 | palenque
# Processing Record 33 of Set 9 | hofn
# Processing Record 34 of Set 9 | senanga
# Processing Record 35 of Set 9 | medvezhyegorsk
# Processing Record 36 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 9 | mount barker
# Processing Record 38 of Set 9 | kallupatti
# Processing Record 39 of Set 9 | teknaf
# Processing Record 40 of Set 9 | las lomas
# Processing Record 41 of Set 9 | auki
# Processing Record 42 of Set 9 | acapulco
# Processing Record 43 of Set 9 | sabha
# Processing Record 44 of Set 9 | san joaquin
# Processing Record 45 of Set 9 | bathsheba
# Processing Record 46 of Set 9 | harper
# Processing Record 47 of Set 9 | mbandaka
# Processing Record 48 of Set 9 | ust-uda
# Processing Record 49 of Set 9 | merritt
# Processing Record 50 of Set 9 | trairi
# Processing Record 1 of Set 10 | california city
# Processing Record 2 of Set 10 | santiago do cacem
# Processing Record 3 of Set 10 | saint anthony
# Processing Record 4 of Set 10 | vila franca do campo
# Processing Record 5 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 6 of Set 10 | candelaria
# Processing Record 7 of Set 10 | kirksville
# Processing Record 8 of Set 10 | pointe michel
# Processing Record 9 of Set 10 | mariental
# Processing Record 10 of Set 10 | berdigestyakh
# Processing Record 11 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 10 | conceicao do rio verde
# Processing Record 13 of Set 10 | nong han
# Processing Record 14 of Set 10 | plouzane
# Processing Record 15 of Set 10 | walvis bay
# Processing Record 16 of Set 10 | iquique
# Processing Record 17 of Set 10 | troitskoye
# Processing Record 18 of Set 10 | sioux lookout
# Processing Record 19 of Set 10 | muros
# Processing Record 20 of Set 10 | puerto del rosario
# Processing Record 21 of Set 10 | charkhi dadri
# Processing Record 22 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 10 | fare
# Processing Record 24 of Set 10 | genhe
# Processing Record 25 of Set 10 | havelock
# Processing Record 26 of Set 10 | ostrovnoy
# Processing Record 27 of Set 10 | sampit
# Processing Record 28 of Set 10 | isla mujeres
# Processing Record 29 of Set 10 | bull savanna
# Processing Record 30 of Set 10 | starosubkhangulovo
# Processing Record 31 of Set 10 | duns
# Processing Record 32 of Set 10 | arman
# Processing Record 33 of Set 10 | tessalit
# Processing Record 34 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 35 of Set 10 | minas
# Processing Record 36 of Set 10 | saint-joseph
# Processing Record 37 of Set 10 | nicoya
# Processing Record 38 of Set 10 | urusha
# Processing Record 39 of Set 10 | prado
# Processing Record 40 of Set 10 | trat
# Processing Record 41 of Set 10 | neiafu
# Processing Record 42 of Set 10 | arica
# Processing Record 43 of Set 10 | sovetskiy
# Processing Record 44 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 10 | saveh
# Processing Record 46 of Set 10 | orlik
# Processing Record 47 of Set 10 | ugoofaaru
# Processing Record 48 of Set 10 | cap malheureux
# Processing Record 49 of Set 10 | bosaso
# Processing Record 50 of Set 10 | nizhniy kuranakh
# Processing Record 1 of Set 11 | guerrero negro
# Processing Record 2 of Set 11 | lucea
# Processing Record 3 of Set 11 | riyadh
# Processing Record 4 of Set 11 | namatanai
# Processing Record 5 of Set 11 | hanzhong
# Processing Record 6 of Set 11 | north fort myers
# Processing Record 7 of Set 11 | ksenyevka
# City not found. Skipping...
# Processing Record 8 of Set 11 | codajas
# Processing Record 9 of Set 11 | caluquembe
# Processing Record 10 of Set 11 | vaitape
# Processing Record 11 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 11 | turayf
# Processing Record 13 of Set 11 | okha
# Processing Record 14 of Set 11 | along
# Processing Record 15 of Set 11 | airai
# Processing Record 16 of Set 11 | mus
# Processing Record 17 of Set 11 | mandera
# Processing Record 18 of Set 11 | ardabil
# Processing Record 19 of Set 11 | alberton
# Processing Record 20 of Set 11 | niono
# Processing Record 21 of Set 11 | victoria point
# Processing Record 22 of Set 11 | tommot
# Processing Record 23 of Set 11 | huntington
# Processing Record 24 of Set 11 | wattegama
# Processing Record 25 of Set 11 | owensboro
# Processing Record 26 of Set 11 | sahiwal
# Processing Record 27 of Set 11 | charagua
# Processing Record 28 of Set 11 | malaryta
# Processing Record 29 of Set 11 | xinyu
# Processing Record 30 of Set 11 | buala
# Processing Record 31 of Set 11 | hoquiam
# Processing Record 32 of Set 11 | half moon bay
# Processing Record 33 of Set 11 | ejido
# Processing Record 34 of Set 11 | saint-georges
# Processing Record 35 of Set 11 | iqaluit
# Processing Record 36 of Set 11 | khani
# Processing Record 37 of Set 11 | naron
# Processing Record 38 of Set 11 | zharkent
# Processing Record 39 of Set 11 | boguchany
# Processing Record 40 of Set 11 | xiongyue
# Processing Record 41 of Set 11 | casper
# Processing Record 42 of Set 11 | red bank
# Processing Record 43 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 11 | puerto colombia
# Processing Record 45 of Set 11 | te anau
# Processing Record 46 of Set 11 | bakel
# Processing Record 47 of Set 11 | ivdel
# Processing Record 48 of Set 11 | ahipara
# Processing Record 49 of Set 11 | toora-khem
# Processing Record 50 of Set 11 | gidole
# Processing Record 1 of Set 12 | gizo
# Processing Record 2 of Set 12 | falavarjan
# Processing Record 3 of Set 12 | leningradskiy
# Processing Record 4 of Set 12 | oussouye
# Processing Record 5 of Set 12 | lafia
# Processing Record 6 of Set 12 | dabola
# Processing Record 7 of Set 12 | takoradi
# Processing Record 8 of Set 12 | khorramshahr
# Processing Record 9 of Set 12 | aswan
# Processing Record 10 of Set 12 | belmonte
# Processing Record 11 of Set 12 | araguatins
# City not found. Skipping...
# Processing Record 12 of Set 12 | leshukonskoye
# Processing Record 13 of Set 12 | owatonna
# Processing Record 14 of Set 12 | westport
# Processing Record 15 of Set 12 | ternate
# Processing Record 16 of Set 12 | salantai
# Processing Record 17 of Set 12 | pauini
# Processing Record 18 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 19 of Set 12 | mariahu
# Processing Record 20 of Set 12 | general pico
# Processing Record 21 of Set 12 | ucluelet
# Processing Record 22 of Set 12 | lagoa
# Processing Record 23 of Set 12 | sivas
# Processing Record 24 of Set 12 | pindi gheb
# Processing Record 25 of Set 12 | mikkeli
# Processing Record 26 of Set 12 | talawdi
# City not found. Skipping...
# Processing Record 27 of Set 12 | bay city
# Processing Record 28 of Set 12 | bambanglipuro
# Processing Record 29 of Set 12 | olafsvik
# Processing Record 30 of Set 12 | cachoeirinha
# Processing Record 31 of Set 12 | itaqui
# Processing Record 32 of Set 12 | liverpool
# Processing Record 33 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 12 | sistranda
# Processing Record 35 of Set 12 | kariba
# Processing Record 36 of Set 12 | burayevo
# Processing Record 37 of Set 12 | mao
# Processing Record 38 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 12 | sagaing
# Processing Record 40 of Set 12 | sagua la grande
# Processing Record 41 of Set 12 | conceicao do araguaia
# Processing Record 42 of Set 12 | sinnamary
# Processing Record 43 of Set 12 | ihosy
# Processing Record 44 of Set 12 | maniitsoq
# Processing Record 45 of Set 12 | tomohon
# Processing Record 46 of Set 12 | port macquarie
# Processing Record 47 of Set 12 | hualmay
# Processing Record 48 of Set 12 | lircay
# Processing Record 49 of Set 12 | esil
# Processing Record 50 of Set 12 | kulhudhuffushi
# Processing Record 1 of Set 13 | concepcion
# Processing Record 2 of Set 13 | quang ngai
# Processing Record 3 of Set 13 | saldanha
# Processing Record 4 of Set 13 | adrar
# Processing Record 5 of Set 13 | ust-kuyga
# Processing Record 6 of Set 13 | ust-ishim
# Processing Record 7 of Set 13 | la grande
# Processing Record 8 of Set 13 | khash
# Processing Record 9 of Set 13 | betare oya
# Processing Record 10 of Set 13 | conakry
# Processing Record 11 of Set 13 | orotukan
# Processing Record 12 of Set 13 | rena
# Processing Record 13 of Set 13 | portland
# Processing Record 14 of Set 13 | manavalakurichi
# Processing Record 15 of Set 13 | sal rei
# Processing Record 16 of Set 13 | baranain
# Processing Record 17 of Set 13 | kalynivka
# Processing Record 18 of Set 13 | chimoio
# Processing Record 19 of Set 13 | daan
# Processing Record 20 of Set 13 | yablonovo
# Processing Record 21 of Set 13 | tigre
# Processing Record 22 of Set 13 | muli
# Processing Record 23 of Set 13 | san lawrenz
# Processing Record 24 of Set 13 | mudon
# Processing Record 25 of Set 13 | shieli
# Processing Record 26 of Set 13 | bay roberts
# Processing Record 27 of Set 13 | altamira
# Processing Record 28 of Set 13 | qaqortoq
# Processing Record 29 of Set 13 | tabuk
# Processing Record 30 of Set 13 | imeni poliny osipenko
# Processing Record 31 of Set 13 | yaan
# Processing Record 32 of Set 13 | charters towers
# Processing Record 33 of Set 13 | boende
# Processing Record 34 of Set 13 | skibbereen
# Processing Record 35 of Set 13 | atambua
# Processing Record 36 of Set 13 | anadyr
# Processing Record 37 of Set 13 | kaeo
# Processing Record 38 of Set 13 | umarkot
# Processing Record 39 of Set 13 | awjilah
# Processing Record 40 of Set 13 | chimbote
# Processing Record 41 of Set 13 | najran
# Processing Record 42 of Set 13 | roebourne
# Processing Record 43 of Set 13 | miguel hidalgo
# Processing Record 44 of Set 13 | creston
# Processing Record 45 of Set 13 | tura
# Processing Record 46 of Set 13 | koundara
# Processing Record 47 of Set 13 | octeville
# Processing Record 48 of Set 13 | nouakchott
# Processing Record 49 of Set 13 | atasu
# Processing Record 50 of Set 13 | zemio
# Processing Record 1 of Set 14 | mayo
# Processing Record 2 of Set 14 | inta
# Processing Record 3 of Set 14 | bogande
# Processing Record 4 of Set 14 | dzhebariki-khaya
# Processing Record 5 of Set 14 | kaduna
# Processing Record 6 of Set 14 | port blair
# Processing Record 7 of Set 14 | san juan
# Processing Record 8 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 9 of Set 14 | tiznit
# Processing Record 10 of Set 14 | tumarbong
# Processing Record 11 of Set 14 | foumbot
# Processing Record 12 of Set 14 | pringsewu
# Processing Record 13 of Set 14 | rio grande
# Processing Record 14 of Set 14 | aksarka
# Processing Record 15 of Set 14 | rancho palos verdes
# Processing Record 16 of Set 14 | ust-nera
# Processing Record 17 of Set 14 | winchester
# Processing Record 18 of Set 14 | marawi
# Processing Record 19 of Set 14 | tiarei
# Processing Record 20 of Set 14 | virden
# Processing Record 21 of Set 14 | sola
# Processing Record 22 of Set 14 | bereslavka
# Processing Record 23 of Set 14 | tecolutla
# Processing Record 24 of Set 14 | nenjiang
# Processing Record 25 of Set 14 | constantine
# Processing Record 26 of Set 14 | thinadhoo
# Processing Record 27 of Set 14 | arinos
# Processing Record 28 of Set 14 | gat
# Processing Record 29 of Set 14 | wardenburg
# Processing Record 30 of Set 14 | khasan
# Processing Record 31 of Set 14 | wagar
# Processing Record 32 of Set 14 | kaduy
# Processing Record 33 of Set 14 | chkalovsk
# Processing Record 34 of Set 14 | port alberni
# Processing Record 35 of Set 14 | basco
# Processing Record 36 of Set 14 | waw
# Processing Record 37 of Set 14 | can tho
# Processing Record 38 of Set 14 | dongsheng
# Processing Record 39 of Set 14 | itaituba
# Processing Record 40 of Set 14 | pisco
# Processing Record 41 of Set 14 | leh
# Processing Record 42 of Set 14 | ozinki
# Processing Record 43 of Set 14 | waipawa
# Processing Record 44 of Set 14 | adjumani
# Processing Record 45 of Set 14 | masvingo
# Processing Record 46 of Set 14 | northam
# Processing Record 47 of Set 14 | hanyang
# Processing Record 48 of Set 14 | narang
# Processing Record 49 of Set 14 | broken hill
# Processing Record 50 of Set 14 | lihula
# Processing Record 1 of Set 15 | gumdag
# Processing Record 2 of Set 15 | taos
# Processing Record 3 of Set 15 | makaryev
# Processing Record 4 of Set 15 | dandong
# Processing Record 5 of Set 15 | hastings
# Processing Record 6 of Set 15 | vao
# Processing Record 7 of Set 15 | acajutla
# Processing Record 8 of Set 15 | aykhal
# Processing Record 9 of Set 15 | pacific grove
# Processing Record 10 of Set 15 | mallasamudram
# Processing Record 11 of Set 15 | bourbonnais
# Processing Record 12 of Set 15 | beyneu
# Processing Record 13 of Set 15 | naze
# Processing Record 14 of Set 15 | belaya gora
# Processing Record 15 of Set 15 | nova soure
# Processing Record 16 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 15 | oistins
# Processing Record 18 of Set 15 | decatur
# Processing Record 19 of Set 15 | nanchang
# Processing Record 20 of Set 15 | neryungri
# Processing Record 21 of Set 15 | majene
# Processing Record 22 of Set 15 | yenagoa
# Processing Record 23 of Set 15 | watsa
# Processing Record 24 of Set 15 | nacala
# Processing Record 25 of Set 15 | saint-agapit
# Processing Record 26 of Set 15 | nanlong
# Processing Record 27 of Set 15 | santa isabel do rio negro
# Processing Record 28 of Set 15 | megion
# Processing Record 29 of Set 15 | huarmey
# Processing Record 30 of Set 15 | kantunilkin
# Processing Record 31 of Set 15 | suntar
# Processing Record 32 of Set 15 | coatzintla
# Processing Record 33 of Set 15 | batemans bay
# Processing Record 34 of Set 15 | duz
# City not found. Skipping...
# Processing Record 35 of Set 15 | imeni karla libknekhta
# Processing Record 36 of Set 15 | cockburn town
# Processing Record 37 of Set 15 | buritis
# Processing Record 38 of Set 15 | nuevo imperial
# Processing Record 39 of Set 15 | tabulbah
# City not found. Skipping...
# Processing Record 40 of Set 15 | jaguaribe
# Processing Record 41 of Set 15 | san andres
# Processing Record 42 of Set 15 | banda aceh
# Processing Record 43 of Set 15 | arrah
# Processing Record 44 of Set 15 | steamboat springs
# Processing Record 45 of Set 15 | sao paulo de olivenca
# Processing Record 46 of Set 15 | bengkalis
# City not found. Skipping...
# Processing Record 47 of Set 15 | golden
# Processing Record 48 of Set 15 | dayong
# Processing Record 49 of Set 15 | conde
# Processing Record 50 of Set 15 | ornskoldsvik
# Processing Record 1 of Set 16 | shingu
# Processing Record 2 of Set 16 | burica
# City not found. Skipping...
# Processing Record 3 of Set 16 | winslow
# Processing Record 4 of Set 16 | maamba
# Processing Record 5 of Set 16 | mezen
# Processing Record 6 of Set 16 | dhidhdhoo
# Processing Record 7 of Set 16 | yinchuan
# Processing Record 8 of Set 16 | burnie
# Processing Record 9 of Set 16 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 16 | qostanay
# Processing Record 11 of Set 16 | pennsville
# Processing Record 12 of Set 16 | praia
# Processing Record 13 of Set 16 | talmenka
# Processing Record 14 of Set 16 | kimbe
# Processing Record 15 of Set 16 | kloulklubed
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Date"]
city_data_df = city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
